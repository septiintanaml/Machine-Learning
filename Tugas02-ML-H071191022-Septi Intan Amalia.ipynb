# %% [markdown]
# Nama : Septi Intan Amalia
# Nim : H071191022

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('quality-red.csv',sep=";")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.dropna(inplace=True)
data = df.reset_index(drop=True)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [1599 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

df_scale = data.copy()
scaler = StandardScaler()
df_scale = scaler.fit_transform(df_scale)
len(df_scale)
# Out:
# 1599

# %%
data = pd.DataFrame(df_scale)
data.columns = df.columns
data_cluster = data.copy()
data.head()
data.shape
# Out:
# (1599, 12)

# %%
from sklearn.cluster import KMeans

clusters = []
for i in range (1,11):
    km = KMeans(n_clusters=i).fit(data)
    clusters.append(km.inertia_)

fig, ax = plt.subplots(figsize=(8,4))
sns.lineplot(x=list(range(1,11)), y=clusters, ax=ax)
ax.set_title('Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
model_kmeans3 = KMeans(n_clusters=3)
model_kmeans3.fit(data)
data_cluster['cluster_kmeans3'] = model_kmeans3.labels_
data_cluster
# Out:
#       fixed acidity  volatile acidity  ...   quality  cluster_kmeans3
# 0         -0.528360          0.961877  ... -0.787823                1
# 1         -0.298547          1.967442  ... -0.787823                2
# 2         -0.298547          1.297065  ... -0.787823                1
# 3          1.654856         -1.384443  ...  0.450848                0
# 4         -0.528360          0.961877  ... -0.787823                1
# ...             ...               ...  ...       ...              ...
# 1594      -1.217796          0.403229  ... -0.787823                1
# 1595      -1.390155          0.123905  ...  0.450848                1
# 1596      -1.160343         -0.099554  ...  0.450848                1
# 1597      -1.390155          0.654620  ... -0.787823                1
# 1598      -1.332702         -1.216849  ...  0.450848                1
#
# [1599 rows x 13 columns]

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data_cluster['fixed acidity'], data_cluster['volatile acidity'], hue=data_cluster['cluster_kmeans3'], palette=sns.color_palette('hls',3))
plt.title(' KMeans 3 cluster')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, ' KMeans 3 cluster')

# %% [markdown]
# K-Medoids

# %%
from sklearn_extra.cluster import KMedoids
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-9d4b676b3c6f> in <module>()
# ----> 1 from sklearn_extra.cluster import KMedoids
#
# ModuleNotFoundError: No module named 'sklearn_extra'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model_kmedoids = KMedoids(n_clusters=4, random_state=0)
model_kmedoids.fit(data)
data_cluster['Cluster K-Medoids'] = model_kmedoids.labels_
data_cluster
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-076fbcfd4c1e> in <module>()
# ----> 1 model_kmedoids = KMedoids(n_clusters=4, random_state=0)
#       2 model_kmedoids.fit(data)
#       3 data_cluster['Cluster K-Medoids'] = model_kmedoids.labels_
#       4 data_cluster
#
# NameError: name 'KMedoids' is not defined

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data_cluster['fixed acidity'], data_cluster['volatile acidity'], hue=data_cluster['Cluster K-Medoids'], palette=sns.color_palette('hls',4))
plt.title(' K-Medoids 4 cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cluster K-Medoids'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4d66c6946b35> in <module>()
#       1
#       2 plt.figure(figsize=(8,4))
# ----> 3 sns.scatterplot(data_cluster['fixed acidity'], data_cluster['volatile acidity'], hue=data_cluster['Cluster K-Medoids'], palette=sns.color_palette('hls',4))
#       4 plt.title(' K-Medoids 4 cluster')
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Cluster K-Medoids'

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

plt.figure(figsize=(10,7))
plt.title("Dendrogram")
dend = dendrogram(linkage(data, method="ward"))
plt.axhline(y=35, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering

model_agglo = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')
model_agglo.fit_predict(data)
plt.title('Hierarchy')
plt.figure(figsize=(10,7))
plt.scatter(data_cluster['volatile acidity'], data_cluster['volatile acidity'], c=model_agglo.labels_)

# %%
from sklearn.neighbors import NearestNeighbors

neigh = NearestNeighbors(n_neighbors=13)
nbrs = neigh.fit(data)
distances, indices = nbrs.kneighbors(data)

distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)
plt.axhline(y=1.5, color='r', linestyle='--')

# %%
from sklearn.cluster import DBSCAN

model_dbscan = DBSCAN(eps=1.5, min_samples=13)
model_dbscan.fit(data)
plt.figure(figsize=(10,10))
plt.scatter(data_cluster['fixed acidity'], data_cluster['volatile acidity'], c=model_dbscan.labels_)
plt.title(' DBSCAN clustering')
plt.show()
